# %% [markdown]
# example for variable and datatype

# %%
name="thanu"
age=19
cgpa=8.5
placed=True
print("student name:",name)
print("age",age)
print("cgpa",cgpa)
print("placed",placed)
print(type(name))
print(type(age))
print(type(cgpa))
print(type(placed))
# Out:
# student name: thanu
# age 19
# cgpa 8.5
# placed True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# list

# %%
name=["thanu","kavi","arun"]
marks=[100,80,75]
print(name[0])
print(marks[0])
print(len(marks))
name.append("divya")
print(name)
# Out:
# thanu
# 100
# 3
# ['thanu', 'kavi', 'arun', 'divya']

# %% [markdown]
# tuple

# %%
days=("monday","tuesday","wednesday","thursday","friday")
print(days)
# Out:
# ('monday', 'tuesday', 'wednesday', 'thursday', 'friday')
# january

# %% [markdown]
# dictionary

# %%
student={
    "name":"arun",
    "age":"19"}
print(student)
# Out:
# {'name': 'arun', 'age': '19'}
