# %%
import pandas as pd
df=pd.read_csv("data.csv")
df.head()
# Out:
#   Patient_ID     Patient_Name  Age  Gender    Disease Admission_Date  \
# 0      P0001  Robert Martinez   90    Male   Diabetes     2025-06-14
# 1      P0002     William Diaz   25  Female     Dengue     2025-01-04
# 2      P0003     Larry Weaver   63  Female  Pneumonia     2024-01-12
# 3      P0004      Megan Green   63  Female     Dengue     2025-02-09
# 4      P0005       Joseph Lee   84    Male     Dengue     2024-11-09
#
#   Discharge_Date   Doctor_Name        Department  Treatment_Cost
# 0     2025-06-22     Dr. Huber     Endocrinology          100926
# 1     2025-01-11     Dr. Roman  General Medicine           35540
# 2     2024-01-27    Dr. Finley       Pulmonology           41172
# 3     2025-02-17     Dr. Clark  General Medicine           27898
# 4     2024-11-16  Dr. Anderson  General Medicine          142542

# %%
df.tail()
# Out:
#     Patient_ID     Patient_Name  Age  Gender        Disease Admission_Date  \
# 995      P0996      Teresa Mack   21    Male  Heart Disease     2024-02-22
# 996      P0997  David Cervantes   64    Male        Typhoid     2025-11-30
# 997      P0998     Ruben Wright   10  Female       Migraine     2024-02-08
# 998      P0999    William Velez   74    Male      Arthritis     2024-08-18
# 999      P1000     Katie Murray   27    Male       Migraine     2025-10-01
#
#     Discharge_Date    Doctor_Name        Department  Treatment_Cost
# 995     2024-02-26  Dr. Nicholson        Cardiology          131595
# 996     2025-12-12  Dr. Fernandez  General Medicine           55220
# 997     2024-02-19     Dr. Flores         Neurology          140955
# 998     2024-08-22      Dr. Smith       Orthopedics           46615
# 999     2025-10-16   Dr. Franklin         Neurology            9842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      1000 non-null   object
#  1   Patient_Name    1000 non-null   object
#  2   Age             1000 non-null   int64
#  3   Gender          1000 non-null   object
#  4   Disease         1000 non-null   object
#  5   Admission_Date  1000 non-null   object
#  6   Discharge_Date  1000 non-null   object
#  7   Doctor_Name     1000 non-null   object
#  8   Department      1000 non-null   object
#  9   Treatment_Cost  1000 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 78.3+ KB

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Patient_Name', 'Age', 'Gender', 'Disease',
#        'Admission_Date', 'Discharge_Date', 'Doctor_Name', 'Department',
#        'Treatment_Cost'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age  Treatment_Cost
# count  1000.000000     1000.000000
# mean     44.705000    77082.768000
# std      25.888495    40593.085523
# min       1.000000     5213.000000
# 25%      23.000000    42566.750000
# 50%      44.000000    75597.500000
# 75%      67.000000   111503.000000
# max      90.000000   149926.000000

# %%
df.isnull().sum()
# Out:
# Patient_ID        0
# Patient_Name      0
# Age               0
# Gender            0
# Disease           0
# Admission_Date    0
# Discharge_Date    0
# Doctor_Name       0
# Department        0
# Treatment_Cost    0
# dtype: int64

# %% [markdown]
# Total no of paitents

# %%
total_patients = df['Patient_ID'].nunique()
print(f"Total number of patients: {total_patients}")
# Out:
# Total number of patients: 1000

# %% [markdown]
# average cost of treatment

# %%
average_treatment_cost = df['Treatment_Cost'].mean()
print(f"Average treatment cost per patient: {average_treatment_cost:.2f}")
# Out:
# Average treatment cost per patient: 77082.77
